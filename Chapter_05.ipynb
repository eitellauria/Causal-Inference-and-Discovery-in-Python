# %% [markdown]
# <a href="https://colab.research.google.com/github/eitellauria/Causal-Inference-and-Discovery-in-Python/blob/main/Chapter_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import combinations

import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import graphviz

# %%
COLORS = [
    '#00B0F0',
    '#FF0000',
    '#B0F000'
]

# %% [markdown]
# # Chapter 05
#
# This chapter introduces the concept of mapping between distributions and graphs. We define and demonstrate basic graphical structures and (briefly) talk about statistical and graphical independence. Finally, we implement regression models to show how different graphical structures manifest themselves in statistical (in)dependencies.

# %% [markdown]
# ## Visualizations

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,2.75!', '2,3!', '0,1!']

edges = ['AB', 'CB', 'CA']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_markov_01')

graph

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,2.75!', '2,3!', '0,1!']

edges = ['AB', 'CB', 'AC']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_markov_02')

graph

# %% [markdown]
# ## Causal graphs and independence

# %%
NOISE_LEVEL = .2
N_SAMPLES = 1000

# %% [markdown]
# ### A chain: `A -> B -> C`

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,0!', '1.5,0!', '3,0!']

edges = ['AB', 'BC']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_chain_00')

graph

# %%
# Generate the data
a = np.random.randn(N_SAMPLES)
b = a + NOISE_LEVEL*np.random.randn(N_SAMPLES)
c = b + NOISE_LEVEL*np.random.randn(N_SAMPLES)

# Get combinations
combs = list(combinations([('a', a), ('b', b), ('c', c)], 2))

# %%
# Plot
plt.figure(figsize=(12, 8))

for i, comb in enumerate(combs):
    key_1, key_2 = comb[0][0], comb[1][0]


    plt.subplot(2, 2, i + 1)
    plt.scatter(comb[0][1], comb[1][1], alpha=.5, color=COLORS[0])
    plt.xlabel(key_1)
    plt.ylabel(key_2)

plt.suptitle('Chain - scatterplots')
plt.show()

# %%
X = pd.DataFrame(np.vstack([a, b]).T, columns=['A', 'B'])
X = sm.add_constant(X, prepend=True)

model = sm.OLS(c, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                 1.191e+04
# Date:                Wed, 20 Dec 2023   Prob (F-statistic):               0.00
# Time:                        20:42:51   Log-Likelihood:                 166.28
# No. Observations:                1000   AIC:                            -326.6
# Df Residuals:                     997   BIC:                            -311.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.006      0.290      0.772      -0.011       0.015
# A             -0.0096      0.032     -0.301      0.764      -0.072       0.053
# B              1.0058      0.031     32.225      0.000       0.945       1.067
# ==============================================================================
# Omnibus:                        1.286   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.526   Jarque-Bera (JB):                1.190
# Skew:                          -0.081   Prob(JB):                        0.552
# Kurtosis:                       3.051   Cond. No.                         9.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### A fork: `A <- B -> C`

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,0!', '1.5,0!', '3,0!']

edges = ['BA', 'BC']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_fork_00')

graph

# %%
# Generate the data
b = np.random.randn(N_SAMPLES)
a = b + NOISE_LEVEL*np.random.randn(N_SAMPLES)
c = b + NOISE_LEVEL*np.random.randn(N_SAMPLES)

# Get combinations
combs = list(combinations([('a', a), ('b', b), ('c', c)], 2))

# %%
# Plot
plt.figure(figsize=(12, 8))

for i, comb in enumerate(combs):
    key_1, key_2 = comb[0][0], comb[1][0]


    plt.subplot(2, 2, i + 1)
    plt.scatter(comb[0][1], comb[1][1], alpha=.5, color=COLORS[0])
    plt.xlabel(key_1)
    plt.ylabel(key_2)

plt.suptitle('Fork - scatterplots')
plt.show()

# %%
X = pd.DataFrame(np.vstack([a, b]).T, columns=['A', 'B'])
X = sm.add_constant(X, prepend=True)

model = sm.OLS(c, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                 1.366e+04
# Date:                Wed, 20 Dec 2023   Prob (F-statistic):               0.00
# Time:                        20:42:53   Log-Likelihood:                 254.70
# No. Observations:                1000   AIC:                            -503.4
# Df Residuals:                     997   BIC:                            -488.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0154      0.006     -2.590      0.010      -0.027      -0.004
# A             -0.0466      0.030     -1.549      0.122      -0.106       0.012
# B              1.0424      0.031     33.763      0.000       0.982       1.103
# ==============================================================================
# Omnibus:                        1.438   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.487   Jarque-Bera (JB):                1.390
# Skew:                          -0.091   Prob(JB):                        0.499
# Kurtosis:                       3.014   Cond. No.                         10.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### A collider: `A -> B <- C`

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,0!', '1.5,0!', '3,0!']

edges = ['AB', 'CB']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_collider_00')

graph

# %%
# Generate the data
a = np.random.randn(N_SAMPLES)
c = np.random.randn(N_SAMPLES)
b = a + c + NOISE_LEVEL*np.random.randn(N_SAMPLES)

# Get combinations
combs = list(combinations([('a', a), ('b', b), ('c', c)], 2))

# %%
# Plot
plt.figure(figsize=(12, 8))

for i, comb in enumerate(combs):
    key_1, key_2 = comb[0][0], comb[1][0]


    plt.subplot(2, 2, i + 1)
    plt.scatter(comb[0][1], comb[1][1], alpha=.5, color=COLORS[0])
    plt.xlabel(key_1)
    plt.ylabel(key_2)

plt.suptitle('Collider - scatterplots')
plt.show()

# %%
X = pd.DataFrame(np.vstack([a, b]).T, columns=['A', 'B'])
X = sm.add_constant(X, prepend=True)

model = sm.OLS(c, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                 1.063e+04
# Date:                Wed, 20 Dec 2023   Prob (F-statistic):               0.00
# Time:                        20:42:54   Log-Likelihood:                 191.51
# No. Observations:                1000   AIC:                            -377.0
# Df Residuals:                     997   BIC:                            -362.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0079      0.006      1.251      0.211      -0.005       0.020
# A             -0.9641      0.009   -104.157      0.000      -0.982      -0.946
# B              0.9671      0.007    145.822      0.000       0.954       0.980
# ==============================================================================
# Omnibus:                        0.457   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.796   Jarque-Bera (JB):                0.507
# Skew:                          -0.049   Prob(JB):                        0.776
# Kurtosis:                       2.951   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
